# %% [markdown]
# ## Why Descriptive Statistics?
#
# * Inorder to understand more about the sample I have collected were we getting into Descriptive statistics - EDA : Mean, Median, Mode, Standard Deviation, Skewness, Kurtosis, Data Visualization - where we try to analyze the sample in all possible ways. That is called Descriptive analysis.

# %% [markdown]
# ## 1. Import Necessary Libraries.

# %%
#Importing all libraries into the first cell, that's the Good Way to mention all libraries into the first cell.
import pandas as pd #For data manipulation.
import numpy as np  #For Numerical Operations.

import matplotlib.pyplot as plt #For Data Visualization.
import seaborn as sns #For Data Visualization.

from sklearn.preprocessing import StandardScaler #For Data preparation.
from sklearn.preprocessing import LabelEncoder  #For to data transformation.

import warnings
warnings.filterwarnings('ignore') # To ignore warning messages.

# %% [markdown]
# ## 2. Import Dataset.

# %%
#Importing original datset
sales_data = pd.read_csv('sales_data_with_discounts.csv')
sales_data
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %% [markdown]
# ## 3.Data Understanding.

# %%
#For to get first 10 observations.
sales_data.head(10)
# Out:
#          Date       Day  SKU City  Volume       BU    Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles    RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles    RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles     YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles     YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles     YouM      YM-98
# 5  01-04-2021  Thursday  M06    C       3  Mobiles    RealU        RU-9
# 6  01-04-2021  Thursday  M07    C       3  Mobiles  Sumsang        S-20
# 7  01-04-2021  Thursday  M08    C       2  Mobiles  Sumsang        S-21
# 8  01-04-2021  Thursday  M09    C       2  Mobiles   Orange        O-10
# 9  01-04-2021  Thursday  M10    C       3  Mobiles   Orange        O-11
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# ...

# %%
#For to get last 10 observations.
sales_data.tail(10)
# Out:
#            Date       Day  SKU City  Volume         BU  Brand        Model  \
# 440  15-04-2021  Thursday  L01    C      10  Lifestyle  Jeera  M- T Shirts
# 441  15-04-2021  Thursday  L02    C       3  Lifestyle  Jeera    M- Inners
# 442  15-04-2021  Thursday  L03    C       7  Lifestyle   Viva    W-Casuals
# 443  15-04-2021  Thursday  L04    C       3  Lifestyle   Viva     W-Inners
# 444  15-04-2021  Thursday  L05    C       6  Lifestyle  Jeera      M-Jeans
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera    M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva    W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva     W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera    M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera      M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 440        450               4500          16.477998       741.509919
# ...

# %% [markdown]
# ###### Exploring Feature names.
#
# 1. Date: The date of an item or order has been sold
# 2. Day : The day of the week that order or item has been sold
# 3. SKU : SKU stands for 'Stock Keeping Unit'. that means SKU's are retailer codes that helps to track the product and it will used in inventory section.
# 4. City: City Name or City code, where exactly that particular item has been sold.
# 5. Volume: The number of items or products those are sold.
# 6. BU  : "Business Unit" it refers a Division or Department or Sector of an warehouse.Example: medical items, grocery items, electric items departments and etc.
# 7. Brand: A Name, Symbol that businessess use to distinguish their products from compitators.
# 8. Model: Model refers that segment or versions of the product.
# 9. Avg price: The actual or final price of the item.
# 10. Toatl sales value: The Total cost value based on how much items has been sold.
# 11. Discount Rate(%): The percentage of discount will be provided based on the price from the seller or owner.
# 12. Discount Amount: The discount of amount has converted from percentage of discount based on the total price from seller.
# 13. Net Sales Value: The Final price after given all discounts and all for an particular item or product.

# %%
#To check number of rows and columns.
sales_data.shape # This is an Attribute not an Function.
# Out:
# (450, 13)

# %% [markdown]
# ##### Inference:
# * We have 450 records and 13 features in our dataset.

# %%
#Trying to get all information of dataset.
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
#Fetching all null entries or values in my dataset
sales_data.isna().sum()
# Out:
# Date                 0
# Day                  0
# SKU                  0
# City                 0
# Volume               0
# BU                   0
# Brand                0
# Model                0
# Avg Price            0
# Total Sales Value    0
# Discount Rate (%)    0
# Discount Amount      0
# Net Sales Value      0
# dtype: int64

# %%
#Getting percentage of null values in my data
sales_data.isna().sum()/sales_data.shape[0]*100
# Out:
# Date                 0.0
# Day                  0.0
# SKU                  0.0
# City                 0.0
# Volume               0.0
# BU                   0.0
# Brand                0.0
# Model                0.0
# Avg Price            0.0
# Total Sales Value    0.0
# Discount Rate (%)    0.0
# Discount Amount      0.0
# Net Sales Value      0.0
# dtype: float64

# %% [markdown]
# ##### Inference:
# * There is no null entries in my dataset, so we can easily move to next steps.

# %%
#To check Data types of our variables or features.
sales_data.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %% [markdown]
# ##### Inference:
# * Date feature has missclassified data type as object.so we need to convert that feature into datetime.

# %%
#Knowing is there any duplicate values in my dataset.
sales_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Inference:
# * Another one good news is nothing but we dont have any duplicate values in my data.

# %%
#Column names or Feature names.
sales_data.columns.unique()
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
#Sum of items has been sold.
sales_data['Volume'].sum()
# Out:
# 2280

# %% [markdown]
# ###### Inference:
# * There are totally 2280 items has been sold.

# %%
#understanding how many city codes are there in my data.
sales_data['City'].value_counts()
# Out:
# C    450
# Name: City, dtype: int64

# %% [markdown]
# ##### Inference:
# * We have only one City code that is 'C'

# %%
#Exploring The how many departments or Division or Sector are there in my warehouse.
sales_data['BU'].value_counts()
# Out:
# Mobiles      150
# FMCG         150
# Lifestyle    150
# Name: BU, dtype: int64

# %% [markdown]
# ##### Inference:
# ***We have 3 types sectors or departments*** are ther in my warehouse to sell products those are:
# - Mobiles
# - FMCG[Fast-Moving Consumer Goods products]
# - Lifestyle [cosmetic products]

# %% [markdown]
# ### a). Which BU[Department or Sector] has been sold most?.

# %%
#Knowing which sector products has sold more by using grouping function.
sales_data.groupby(by='BU')['Volume'].sum().sort_values(ascending = False)
# Out:
# BU
# FMCG         929
# Lifestyle    710
# Mobiles      641
# Name: Volume, dtype: int64

# %% [markdown]
# ##### Inference:
# * So here we can easily understand that FMCG[Fast-Moving Consumer Goods products] has been ordered or sold most.
# * And important thing is we should give more preference to Fast Moving Consumer Products include packaged foods, beverages, toiletries, cosmetics, cleaning supplies to get more profit and customer satisfication than others outlests.

# %% [markdown]
# ### b). Which Brand has liked most from customers?.

# %%
#Getting idea about which brands are getting likes from customers and selling most.
sales_data.groupby(by=['BU','Brand'])['Volume'].sum()
# Out:
# BU         Brand
# FMCG       Babaji     447
#            Gear       166
#            Vedic      316
# Lifestyle  Jeera      468
#            Viva       242
# Mobiles    Orange      68
#            RealU      284
#            Sumsang     70
#            YouM       219
# Name: Volume, dtype: int64

# %% [markdown]
# ##### Inference:
# * We should focus on Brands on only Babaji and Vedic to get profit business and force to import products from Babaji and vedic thn other brands
# * In Lifestyle products department we should focus on Jeera brand because this brand getting more sales and customers getting satisfication than other brand viva.
# * In Mobiles sector, customer likes to buy RealU and YouM mobiles than other brands, might these RealU and YouM mobiles having Good performance in battery, smooth using and etc...

# %% [markdown]
# ### c). Which Models of Brand are getting orders most?.

# %%
#getting more liked models based on customers likes to buy.
sales_data.groupby(by=['BU','Brand','Model'])['Volume'].sum()
# Out:
# BU         Brand    Model
# FMCG       Babaji   Babaji Cream       79
#                     Babaji Oil        276
#                     Babaji Shampoo     92
#            Gear     Gear BB Cream      43
#                     Gear Cream         35
#                     Gear Oil           52
#                     Gear Shampoo       36
#            Vedic    Vedic Cream       146
#                     Vedic Oil          60
#                     Vedic Shampoo     110
# Lifestyle  Jeera    M- Inners         103
#                     M- T Shirts       165
#                     M-Casuals          59
#                     M-Formals          35
#                     M-Jeans            81
#                     M-Shoes            25
#            Viva     W-Casuals          77
#                     W-Inners           61
#                     W-Lounge           37
#                     W-Western          67
# Mobiles    Orange   O-10               35
#                     O-11               33
# ...

# %% [markdown]
# ##### Inference:
# ***a). FMCG[Fast-Moving Consumer Goods products]***
# - In this FMCG Babaji brand has famous and in their babaji product babaji oil is having highest sales about 276 than all brands and models.
# - And the brand Vedic also given more sales in their products shampoo and cream. so customers getting like to buy these items in FMCG[Fast-Moving Consumer Goods products].
#
# ***b). Lifestyle***
# - In Lifestyle department the customers are getting comfortable in buy models are M- Inners and M- T Shirts, and these models got famous in lifestyle in the particular brand Jeera.
#
# ***c). Mobiles***
# - In mobiles department RealU brand and it's model RU-10 having highest 143 sales. and this model having more features for that reason this particular model got famous and having high sales.

# %%
#Decribing the Numerical features of statistical measures.
sales_data.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %% [markdown]
# ##### Inference: Using these describe function we can easily get all statistical measures including 'Mean', 'Median', 'Standard deviation' and etcc...
# ***a). Volume***
# * The mean or average of volume feature=5.06 and standard deviation=4.23 and Median=4.0
#
# ***b). Avg Price***
# * The mean or average of Avg Price feature=10453.4 and standard deviation=18079.9 and Median=1450.0
#
# ***c). Total Sales Value***
# * The mean or average of Total Sales Value feature=33812.8 and standard deviation=50535.0 and Median=5700.0
#
# ***d). Discount Rate (%)***
# * The mean or average of Discount Rate (%) feature=15.15 and standard deviation=4.2 and Median=16.5
#
# ***e). Discount Amount***
# * The mean or average of Discount Amount feature=3346.4 and standard deviation=4509.9 and Median=988.9
#
# ***e). Net Sales Value***
# * The mean or average of Net Sales Value feature=30466.3 and standard deviation=46358.6 and Median=4677.7

# %%
#It generates the descriptive of statistical measures for all variables.
sales_data.describe(include='all')
# Out:
#               Date       Day  SKU City      Volume       BU  Brand  Model  \
# count          450       450  450  450  450.000000      450    450    450
# unique          15         7   30    1         NaN        3      9     30
# top     01-04-2021  Thursday  M01    C         NaN  Mobiles  Jeera  RU-10
# freq            30        90   15  450         NaN      150     90     15
# mean           NaN       NaN  NaN  NaN    5.066667      NaN    NaN    NaN
# std            NaN       NaN  NaN  NaN    4.231602      NaN    NaN    NaN
# min            NaN       NaN  NaN  NaN    1.000000      NaN    NaN    NaN
# 25%            NaN       NaN  NaN  NaN    3.000000      NaN    NaN    NaN
# 50%            NaN       NaN  NaN  NaN    4.000000      NaN    NaN    NaN
# 75%            NaN       NaN  NaN  NaN    6.000000      NaN    NaN    NaN
# max            NaN       NaN  NaN  NaN   31.000000      NaN    NaN    NaN
#
#            Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %% [markdown]
# ### 3.1 Let's Visualize our datset for to understanding more.
#
# * The importance of data visualization is simple: ***it helps people see, interact with, and better understand data. Whether simple or complex, the right visualization can bring everyone on the same page, regardless of their level of expertise.***
# * For to visualize the data we will use two  important libraries are matplotlib and seaborn
#
#
# * Matplotlib - To visualize and more customization
# * Seaborn    - To visualize and more beautification

# %%
sales_data.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %% [markdown]
# #### a) Histogram.
#
# * To understand the distribution of data.
# * To check normality of data

# %%
#Ploting histogram on volume feature
plt.figure(figsize=(6,4))
plt.hist(x ='Volume', data = sales_data)
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.title('Volume Distribution',size = 15)
plt.show()

# %% [markdown]
# ###### Inference:
#
# * The distribution of volume is not following the normla distribution.
# * It having right skewed data.
# * Mean > Median.

# %%
#Ploting histogram on Avg Price feature
plt.figure(figsize=(8,4))
plt.hist(x ='Avg Price', data = sales_data)
plt.xlabel('Avg Price')
plt.ylabel('Frequency')
plt.title('Avg Price Distribution',size = 15)
plt.show()

# %% [markdown]
# ###### Inference:
#
# * The distribution of Avg Price is not following the normla distribution.
# * It having right skewed data.
# * Mean > Median.

# %%
#Ploting histogram on Total Sales Value feature
plt.figure(figsize=(8,4))
plt.hist(x ='Total Sales Value', data = sales_data)
plt.xlabel('Total Sales Value')
plt.ylabel('Frequency')
plt.title('Total Sales Value Distribution',size = 15)
plt.show()

# %% [markdown]
# ###### Inference:
#
# * The distribution of Toatl Sales is not following the normla distribution.
# * It having right skewed data.
# * Mean > Median.

# %%
#Ploting histogram on Discount Rate (%) feature
plt.figure(figsize=(6,4))
plt.hist(x ='Discount Rate (%)', data = sales_data)
plt.xlabel('Discount Rate (%)')
plt.ylabel('Frequency')
plt.title('Discount Rate (%) Distribution',size = 15)
plt.show()

# %% [markdown]
# ###### Inference:
#
# * The distribution of Discount Rate (%) is not following the normla distribution.
# * It having left skewed data.
# * Mean > Median.

# %%
#Ploting histogram on Discount Amount feature
plt.figure(figsize=(6,4))
plt.hist(x ='Discount Amount', data = sales_data)
plt.xlabel('Discount Amount')
plt.ylabel('Frequency')
plt.title('Discount Amount Distribution',size = 15)
plt.show()

# %% [markdown]
# ###### Inference:
#
# * The distribution of Discount Amount is not following the normla distribution.
# * It having right skewed data.
# * Mean > Median.

# %%
#Ploting histogram on Net Sales Value feature
plt.figure(figsize=(8,4))
plt.hist(x ='Net Sales Value', data = sales_data)
plt.xlabel('Net Sales Value')
plt.ylabel('Frequency')
plt.title('Net Sales Value Distribution',size = 15)
plt.show()

# %% [markdown]
# ###### Inference:
#
# * The distribution of Net Sales Value is not following the normla distribution.
# * It having right skewed data.
# * Mean > Median.

# %%
sales_data.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %% [markdown]
# #### b). BoxPlot- [1 continous or discrete v/s Continous]
#
# * To understand the distribution and
# * To check the outliers.

# %%
#Boxplot for Volume
plt.figure(figsize=(6,4))
plt.boxplot(x = 'Volume', data = sales_data)
plt.show()

# %% [markdown]
# ###### Inference:
#
# * The 50% of number of volumes comes under <=4.
# * There are some outliers are there.

# %%
#Boxplot for Avg Price
plt.figure(figsize=(6,4))
plt.boxplot(x = 'Avg Price', data = sales_data)
plt.show()

# %% [markdown]
# ###### Inference:
#
# * The 50% of Avg price comes under <=1450.0.
# * There are some outliers are there.

# %%
#Boxplot for Total Sales Value
plt.figure(figsize=(6,4))
plt.boxplot(x = 'Total Sales Value', data = sales_data)
plt.show()

# %% [markdown]
# ###### Inference:
#
# * The 50% of Total sales value comes under <=5700
# * There are some outliers are there.

# %%
#Boxplot for Discount Rate (%)
plt.figure(figsize=(6,4))
plt.boxplot(x = 'Discount Rate (%)', data = sales_data)
plt.show()

# %% [markdown]
# ###### Inference:
#
# * The 50% of Discount Rate (%) comes under <=16.57
# * There are some outliers are there.

# %%
#Boxplot for Discount Amount
plt.figure(figsize=(6,4))
plt.boxplot(x = 'Discount Amount', data = sales_data)
plt.show()

# %% [markdown]
# ###### Inference:
#
# * The 50% of Discount Amount comes under <=988.9
# * There are some outliers are there.

# %%
#Boxplot for Net Sales Value
plt.figure(figsize=(6,4))
plt.boxplot(x = 'Net Sales Value', data = sales_data)
plt.show()

# %% [markdown]
# ###### Inference:
#
# * The 50% of Net Sales Value comes under <=4677.7
# * There are some outliers are there.

# %%
#Ploting boxplot for Bivariate analysis.
plt.figure(figsize=(10,6))
sns.boxplot(sales_data)
# Out:
# <Axes: >

# %%
sales_data.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %% [markdown]
# ### c). Bar Chart Analysis for Categorical Column
#
# * Barchart will be used for **To compare one over the another**.
# * It take both continous data and Discrete data.

# %%
#Barplot betwwen Volume and Discount Rate.
plt.figure(figsize=(10,5))
sns.barplot(x = 'Volume', y = 'Discount Rate (%)', data = sales_data)
plt.title('Volume vs Discount Rate(%)', size = 15)
plt.show()

# %% [markdown]
# ###### Inference:
# * The minimum discount Rate is 14%.
# * The maximum discount Rate is 20%.
# * If the customer wants to buy >=16 quantity then he will be eligible to take >=17.5% discount.
# * There is not much fluctuation between Discount Rate(%) and Volume.

# %%
#Comparing which sector has got more orders or sales.
plt.figure(figsize=(8,4))
sns.barplot(x = 'BU', y = 'Volume', data = sales_data)
plt.title('Volume vs BU', size = 15)
plt.show()

# %% [markdown]
# ###### Inference:
# * Based on all sectors or departments FMCG products got more sales.

# %%
#Comparing the discount rate between models.
plt.figure(figsize=(30,10))
sns.barplot(x = 'Model', y = 'Discount Rate (%)', data = sales_data)
plt.title('Discount Rate (%) vs Model', size = 15)
plt.show()

# %% [markdown]
# ###### Inference:
# * Samsung mobile models having less discount than other models on all departments.

# %%
#Comparing which sector having more net value.
plt.figure(figsize=(30,15))
sns.barplot(x = 'BU', y = 'Net Sales Value', data = sales_data)
plt.title('BU vs Net Sales Value', size = 20)
plt.show()

# %% [markdown]
# ###### Inference:
# * The mobiles sector having high Net value,
# * Here mobiles are getting less orders than others but eah mobile models having high price than other products from different departments or sectors.

# %%
#Comparing which items having high price.
plt.figure(figsize=(30,15))
sns.barplot(x = 'Brand', y = 'Avg Price', data = sales_data)
plt.title('BU vs Net Sales Value', size = 20)
plt.show()

# %% [markdown]
# #### Inference:
# * Here we can easily understand which product having high price and low price.
# * Other than all products or items mobile products comes from different brands are having high price.
# * Orange and Samsang mobiles are having high price and low discount Rate(%).
# * FMCG babaji and vedic products having least price but these products are getting more orders and having high discount rate(%).

# %%
#understanding the net sales value based on city.
sns.scatterplot(data = sales_data, x = 'City', y = 'Net Sales Value')
plt.show()

# %%
#The relation between sales value and net sales value
sns.scatterplot(data = sales_data, x = 'Total Sales Value', y = 'Net Sales Value')
plt.show()

# %% [markdown]
# ###### Inference:
# * There is no difference between net sales value and total sales value, it's co-related.

# %%
#Multivariate analysis
sns.pairplot(data = sales_data)

# %% [markdown]
# ###### Inference:
# * Pairplot will be used for to multivariate analysis.
# * uisng this plot i can see the all the relations between features.

# %%
#Correlation between numerical features
corr = sales_data.corr()
corr
# Out:
#                      Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# Volume             1.000000  -0.250878          -0.034789           0.157972
# Avg Price         -0.250878   1.000000           0.831978          -0.831582
# Total Sales Value -0.034789   0.831978           1.000000          -0.835431
# Discount Rate (%)  0.157972  -0.831582          -0.835431           1.000000
# Discount Amount    0.066297   0.676007           0.932410          -0.657607
# Net Sales Value   -0.044373   0.841166           0.999382          -0.846720
#
#                    Discount Amount  Net Sales Value
# Volume                    0.066297        -0.044373
# Avg Price                 0.676007         0.841166
# Total Sales Value         0.932410         0.999382
# Discount Rate (%)        -0.657607        -0.846720
# Discount Amount           1.000000         0.919127
# Net Sales Value           0.919127         1.000000

# %%
sns.heatmap(data = corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ###### Inference:
# * Using this heatmap we can easily findout features correlation.
# * Total sales value and Discount Amount are correlating.
# * Net sales value and Total sales value are correlating.

# %% [markdown]
# ## 4. Data Preparation.

# %%
sales_data.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
#Removing the City feature from my data
sales_data.drop(labels='City',axis=1,inplace=True)
sales_data.head()
# Out:
#          Date       Day  SKU  Volume       BU  Brand       Model  Avg Price  \
# 0  01-04-2021  Thursday  M01      15  Mobiles  RealU       RU-10      12100
# 1  01-04-2021  Thursday  M02      10  Mobiles  RealU   RU-9 Plus      10100
# 2  01-04-2021  Thursday  M03       7  Mobiles   YouM       YM-99      16100
# 3  01-04-2021  Thursday  M04       6  Mobiles   YouM  YM-99 Plus      20100
# 4  01-04-2021  Thursday  M05       3  Mobiles   YouM      YM-98        8100
#
#    Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value
# 0             181500          11.654820     21153.498820    160346.501180
# 1             101000          11.560498     11676.102961     89323.897039
# 2             112700           9.456886     10657.910157    102042.089843
# 3             120600           6.935385      8364.074702    112235.925298
# 4              24300          17.995663      4372.946230     19927.053770

# %%
#Confirming the shape of our datset after removing the column.
sales_data.shape# Attribute not an function
# Out:
# (450, 12)

# %% [markdown]
# ###### Inference:
# * We having only one city that has mentioned code in C.
# * This feature will not impact our analysis, so im removing that city feature.
# * Now we have 12 features out of city.

# %%
sales_data['Day'].value_counts()
# Out:
# Thursday     90
# Friday       60
# Saturday     60
# Sunday       60
# Monday       60
# Tuesday      60
# Wednesday    60
# Name: Day, dtype: int64

# %%
#Data types
sales_data.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
#Converting date datatype into 'datetime'
sales_data['Date'] = pd.to_datetime(sales_data['Date'])

# %% [markdown]
# ###### Inference:
# * Conversion on of one datatype into another one is called ***Type Casting***.

# %%
#Confirming the datatypes.
sales_data.dtypes
# Out:
# Date                 datetime64[ns]
# Day                          object
# SKU                          object
# Volume                        int64
# BU                           object
# Brand                        object
# Model                        object
# Avg Price                     int64
# Total Sales Value             int64
# Discount Rate (%)           float64
# Discount Amount             float64
# Net Sales Value             float64
# dtype: object

# %% [markdown]
# ### 4.1 Adding New column "profit".

# %% [markdown]
# Profit= ***NET SALES VALUE(t) - NET SALES VALUE(t-1) / NET SALES VALUE(t-1)***

# %%
#Adding New Column "Profit"
sales_data['Profit'] = sales_data['Net Sales Value'].pct_change(periods=1)#pct_change is amethod to caluclate percentage.
sales_data
# Out:
#           Date       Day  SKU  Volume         BU  Brand       Model  \
# 0   2021-01-04  Thursday  M01      15    Mobiles  RealU       RU-10
# 1   2021-01-04  Thursday  M02      10    Mobiles  RealU   RU-9 Plus
# 2   2021-01-04  Thursday  M03       7    Mobiles   YouM       YM-99
# 3   2021-01-04  Thursday  M04       6    Mobiles   YouM  YM-99 Plus
# 4   2021-01-04  Thursday  M05       3    Mobiles   YouM      YM-98
# ..         ...       ...  ...     ...        ...    ...         ...
# 445 2021-04-15  Thursday  L06       2  Lifestyle  Jeera   M-Casuals
# 446 2021-04-15  Thursday  L07       6  Lifestyle   Viva   W-Western
# 447 2021-04-15  Thursday  L08       2  Lifestyle   Viva    W-Lounge
# 448 2021-04-15  Thursday  L09       3  Lifestyle  Jeera   M-Formals
# 449 2021-04-15  Thursday  L10       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        12100             181500          11.654820     21153.498820
# ...

# %%
sales_data.dtypes
# Out:
# Date                 datetime64[ns]
# Day                          object
# SKU                          object
# Volume                        int64
# BU                           object
# Brand                        object
# Model                        object
# Avg Price                     int64
# Total Sales Value             int64
# Discount Rate (%)           float64
# Discount Amount             float64
# Net Sales Value             float64
# Profit                      float64
# dtype: object

# %% [markdown]
# ### 4.2 Conversion of Categorical Data into Dummy Variables

# %% [markdown]
# The most of the input variables or features are not showing direct linear relationship with outputvariable or feature, so we have to do some transformation to make linear.

# %% [markdown]
# #### Data transformation techniques if the data is continous.
# 1. Log Transformation.
# 2. Standard scalar.
# 3. Min-Max scalar.
# 4. Square root transformation and etc....

# %% [markdown]
# #### Data transformation techniques if the data is discrete.
# 1. Label-encoding.
# 2. One-Hot encoding

# %% [markdown]
# ***One hot encoding*** : is a technique that we use to represent categorical variables as numerical values in a machine learning model. The advantages of using one hot encoding include: It allows the use of categorical variables in models that require numerical input.

# %% [markdown]
# ***Label Encoding*** : makes it possible for algorithms to interpret and comprehend the data by giving each category within a variable a distinct number.

# %%
sales_data.head()
# Out:
#         Date       Day  SKU  Volume       BU  Brand       Model  Avg Price  \
# 0 2021-01-04  Thursday  M01      15  Mobiles  RealU       RU-10      12100
# 1 2021-01-04  Thursday  M02      10  Mobiles  RealU   RU-9 Plus      10100
# 2 2021-01-04  Thursday  M03       7  Mobiles   YouM       YM-99      16100
# 3 2021-01-04  Thursday  M04       6  Mobiles   YouM  YM-99 Plus      20100
# 4 2021-01-04  Thursday  M05       3  Mobiles   YouM      YM-98        8100
#
#    Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value  \
# 0             181500          11.654820     21153.498820    160346.501180
# 1             101000          11.560498     11676.102961     89323.897039
# 2             112700           9.456886     10657.910157    102042.089843
# 3             120600           6.935385      8364.074702    112235.925298
# 4              24300          17.995663      4372.946230     19927.053770
#
#      Profit
# 0       NaN
# 1 -0.442932
# 2  0.142383
# 3  0.099898
# ...

# %%
sales_data.dtypes
# Out:
# Date                 datetime64[ns]
# Day                          object
# SKU                          object
# Volume                        int64
# BU                           object
# Brand                        object
# Model                        object
# Avg Price                     int64
# Total Sales Value             int64
# Discount Rate (%)           float64
# Discount Amount             float64
# Net Sales Value             float64
# Profit                      float64
# dtype: object

# %%
# Transforming all categorical features into numerical data by using label encoder transformation method.
encoder = LabelEncoder()
sales_data['Day'] = encoder.fit_transform(sales_data['Day'])
sales_data['SKU'] = encoder.fit_transform(sales_data['SKU'])
sales_data['BU'] = encoder.fit_transform(sales_data['BU'])
sales_data['Brand'] = encoder.fit_transform(sales_data['Brand'])
sales_data['Model'] = encoder.fit_transform(sales_data['Model'])
sales_data
# Out:
#           Date  Day  SKU  Volume  BU  Brand  Model  Avg Price  \
# 0   2021-01-04    4   20      15   2      4     15      12100
# 1   2021-01-04    4   21      10   2      4     17      10100
# 2   2021-01-04    4   22       7   2      8     28      16100
# 3   2021-01-04    4   23       6   2      8     29      20100
# 4   2021-01-04    4   24       3   2      8     27       8100
# ..         ...  ...  ...     ...  ..    ...    ...        ...
# 445 2021-04-15    4   15       2   1      2      9       1300
# 446 2021-04-15    4   16       6   1      7     26       2600
# 447 2021-04-15    4   17       2   1      7     25       1600
# 448 2021-04-15    4   18       3   1      2     10       1900
# 449 2021-04-15    4   19       1   1      2     12       3100
#
#      Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value  \
# 0               181500          11.654820     21153.498820    160346.501180
# ...

# %% [markdown]
# ### 4.3 Standardization of Numerical Variables

# %% [markdown]
# #### 1. Why we need to do standardize?.
#
# => Because data standardization helps to improve the quality of our data by transforming and standardizing.

# %% [markdown]
# #### 2. When we have to do standardize?
#
# => When our data varying that's the time we should do standardize the data.

# %% [markdown]
# #### 3. How do we do standardize the data?
#
# => Using **Z-score**, is one of the most technique for to do standardize the data. And can be done by subtracting the mean and dividing by the standard deviation for each value of each of each feature.

# %%
X = sales_data.drop(labels= 'Date',axis =1)

# %%
X
# Out:
#      Day  SKU  Volume  BU  Brand  Model  Avg Price  Total Sales Value  \
# 0      4   20      15   2      4     15      12100             181500
# 1      4   21      10   2      4     17      10100             101000
# 2      4   22       7   2      8     28      16100             112700
# 3      4   23       6   2      8     29      20100             120600
# 4      4   24       3   2      8     27       8100              24300
# ..   ...  ...     ...  ..    ...    ...        ...                ...
# 445    4   15       2   1      2      9       1300               2600
# 446    4   16       6   1      7     26       2600              15600
# 447    4   17       2   1      7     25       1600               3200
# 448    4   18       3   1      2     10       1900               5700
# 449    4   19       1   1      2     12       3100               3100
#
#      Discount Rate (%)  Discount Amount  Net Sales Value    Profit
# ...

# %%
#Standardization using Z-scalar
scaled = StandardScaler()
scaled_data = scaled.fit_transform(X)
final_data = pd.DataFrame(data= scaled_data,columns=X.columns)
final_data
# Out:
#          Day       SKU    Volume        BU     Brand     Model  Avg Price  \
# 0    0.47907  0.635438  2.350029  1.224745  0.076176  0.057767   0.091173
# 1    0.47907  0.750973  1.167129  1.224745  0.076176  0.288836  -0.019570
# 2    0.47907  0.866507  0.457388  1.224745  1.599686  1.559712   0.312659
# 3    0.47907  0.982041  0.220808  1.224745  1.599686  1.675247   0.534146
# 4    0.47907  1.097575 -0.488932  1.224745  1.599686  1.444178  -0.130313
# ..       ...       ...       ...       ...       ...       ...        ...
# 445  0.47907  0.057767 -0.725512  0.000000 -0.685580 -0.635438  -0.506840
# 446  0.47907  0.173301  0.220808  0.000000  1.218808  1.328644  -0.434857
# 447  0.47907  0.288836 -0.725512  0.000000  1.218808  1.213110  -0.490229
# 448  0.47907  0.404370 -0.488932  0.000000 -0.685580 -0.519904  -0.473617
# 449  0.47907  0.519904 -0.962092  0.000000 -0.685580 -0.288836  -0.407171
#
#      Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value  \
# ...

# %% [markdown]
# ## ***************************************************************************************************************
